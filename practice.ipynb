# %%
import pandas as pd

# %%
data = pd.read_csv("Data/train.csv") # reads the csv file and returns a DataFrame

# %%
data.sample() # gives a random sample of rows from the DataFrame
# Out:
#      PassengerId  Survived  Pclass               Name   Sex  Age  SibSp  \
# 295          296         0       1  Lewy, Mr. Ervin G  male  NaN      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 295      0  PC 17612  27.7208   NaN        C

# %%
data.info() # gives information about the DataFrame, like number of rows, columns, data types, memory usage, etc.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
data.isnull().sum() # gives the count of missing values in each column of the DataFrame
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean()) # fills the missing values in the "Age" column with the mean of the column.
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isnull().sum() # gives the number of null values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked'] = df['Embarked'].bfill()

# %%
#df=df.drop(columns='Cabin')

# %%
df.isnull().sum() # gives the number of null values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64
